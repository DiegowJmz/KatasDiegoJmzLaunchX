# %% [markdown]
# # Kata 1

# %% [markdown]
# Ejercicio 1

# %%
from datetime import date

# La fecha de hoy lo hacemos de tipo string
fecha = str(date.today())

# Mostramos la fecha.
print("La fecha del dia de hoy es: " + fecha)
# Out:
# La fecha del dia de hoy es: 2022-02-10

# %% [markdown]
# Ejercico 2

# %%
# Usamos el tip que nos proporciona, y usando el operador de la multiplicacion 
# multiplicamos el dato que nos dan por 11 pardec. 
parsec = 11
lightyears = 3.26156 * parsec

# Aqui solo convertimos los datos de tipo float e int a tipo cadena. 
print(str(parsec) + " parsec, is " + str(lightyears) + " lightyears")
# Out:
# 11 parsec, is 35.877159999999996 lightyears
