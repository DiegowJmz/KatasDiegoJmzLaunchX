# %% [markdown]
# # Kata 8

# %% [markdown]
# Ejercicio 1

# %%
# Definimos planet en forma diccionario con sus respectivas variables 
planet = {
    'name': 'Mars',
    'moons': 2
}

# Para hacer uso de los datos del diccionario, usamor .get y como las lunas es un valor int, lo pasamos a str. 
print("El planeta " + planet.get('name') + " tiene " + str(planet.get('moons')) + " lunas")

# Ahora agregamos la circunferencia polar, actualizando planet

planet['circumference (km)'] = {
    'polar': 6752,
    'equatorial': 6792
}

# Imprimimos 

print(f'{planet["name"]} tiene una circunferencia polar de {planet["circumference (km)"]["polar"]}')
# Out:
# El planeta Mars tiene 2 lunas
# Mars tiene una circunferencia polar de 6752

# %% [markdown]
# Ejercicio 2

# %%
planet_moons = {
    'mercury': 0,
    'venus': 0,
    'earth': 1,
    'mars': 2,
    'jupiter': 79,
    'saturn': 82,
    'uranus': 27,
    'neptune': 14,
    'pluto': 5,
    'haumea': 2,
    'makemake': 1,
    'eris': 1
}

# Obtenemos la lista de las lunas
# Almacenamos los resultados en una variable moons
moons = planet_moons.values()

# Obtenemos el total de planetas
# Almacenamos los resultados en una variable llamada years
planets = len(planet_moons.keys())


# Calcula el total_moons agregando todas las lunas
# Almacena su valor en una variable llamada total_moons

total_moons = 0
for moon in moons:
    total_moons = total_moons + moon

# Calcula el promedio dividiendo el total_moons por el número de planetas
average = total_moons / planets

# Muestra el promedio
print(average)
# Out:
# 17.833333333333332
